# %%
print("Hello")
# Out:
# Hello

# %%
name="Ganesh"
age=20
print(name,age)
# Out:
# Ganesh 20

# %%
x=10
y=3.5
z="Hi"
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
a=10
b=5
print(a+b)
print(a-b)
# Out:
# 15
# 5
